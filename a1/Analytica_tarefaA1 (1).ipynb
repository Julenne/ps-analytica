# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
#1. Comece lendo o arquivo csv para um DataFrame.
data = pd.read_csv("dataset.csv")

df = pd.DataFrame(data)
#2. Visualize os dados em forma de tabela para compreender a estrutura e suas colunas.
df
# Out:
#      ano sigla_uf  expectativa_vida  populacao_urbana  populacao_rural   idhm
# 0   1991       AC             63.72            258520           159198  0.402
# 1   1991       AL             58.10           1482033          1032067  0.370
# 2   1991       AM             63.67           1502754           600489  0.430
# 3   1991       AP             65.05            234131            55266  0.472
# 4   1991       BA             59.94           7016770          4851221  0.386
# ..   ...      ...               ...               ...              ...    ...
# 76  2010       RS             75.38           9100291          1593638  0.746
# 77  2010       SC             76.61           5247913          1000523  0.774
# 78  2010       SE             71.84           1520366           547651  0.665
# 79  2010       SP             75.69          39585251          1676948  0.783
# 80  2010       TO             72.56           1090106           293339  0.699
#
# [81 rows x 6 columns]

# %%
#3. Calcule o IDH medio do brasil no ano de 1991:
#(a) Comece fazendo uma filtragem nas linhas para selecionar apenas os dados
#referentes ao ano de 1991.
filtro = df["ano"] == 1991
df_filtrado = df[filtro]

df_filtrado
# Out:
#      ano sigla_uf  expectativa_vida  populacao_urbana  populacao_rural   idhm
# 0   1991       AC             63.72            258520           159198  0.402
# 1   1991       AL             58.10           1482033          1032067  0.370
# 2   1991       AM             63.67           1502754           600489  0.430
# 3   1991       AP             65.05            234131            55266  0.472
# 4   1991       BA             59.94           7016770          4851221  0.386
# 5   1991       CE             61.76           4162007          2204640  0.405
# 6   1991       DF             68.87           1515889            85205  0.616
# 7   1991       ES             66.17           1924588           676030  0.505
# 8   1991       GO             65.10           3247676           771227  0.487
# 9   1991       MA             58.04           1972421          2957832  0.357
# 10  1991       MG             66.36          11786893          3956259  0.478
# ...

# %%
#(b) Obtenha os valores de IDH.
idh = df_filtrado.iloc[:,5]
idh
# Out:
# 0     0.402
# 1     0.370
# 2     0.430
# 3     0.472
# 4     0.386
# 5     0.405
# 6     0.616
# 7     0.505
# 8     0.487
# 9     0.357
# 10    0.478
# 11    0.488
# 12    0.449
# 13    0.413
# 14    0.382
# 15    0.440
# 16    0.362
# 17    0.507
# 18    0.573
# 19    0.428
# 20    0.407
# 21    0.459
# 22    0.542
# 23    0.543
# 24    0.408
# 25    0.578
# 26    0.369
# Name: idhm, dtype: float64

# %%
#(c) Retorne a media.
media = np.array(idh).mean()
print(media)
# Out:
# 0.45392592592592584

# %%
#4. A partir da lista dos IDHs da quest˜ao anterior retorne os estados que est˜ao
#acima da m´edia, tamb´em no ano de 1991.
#(a) A partir do valor de m´edia filtre o dataframe dos dados de 1991 para apenas
#os que possuem IDH maior que a m´edia.
filtro2 = df["idhm"] > media
df_acimaMedia = df_filtrado[filtro2]
df_acimaMedia
# Out:
# <ipython-input-33-4b8de1d1dc95>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_acimaMedia = df_filtrado[filtro2]
#      ano sigla_uf  expectativa_vida  populacao_urbana  populacao_rural   idhm
# 3   1991       AP             65.05            234131            55266  0.472
# 6   1991       DF             68.87           1515889            85205  0.616
# 7   1991       ES             66.17           1924588           676030  0.505
# 8   1991       GO             65.10           3247676           771227  0.487
# 10  1991       MG             66.36          11786893          3956259  0.478
# 11  1991       MS             66.93           1414447           365926  0.488
# 17  1991       PR             65.71           6197953          2250760  0.507
# 18  1991       RJ             66.42          12199641           608065  0.573
# 21  1991       RR             62.66            140818            76765  0.459
# ...

# %%
#(b) Retorne os estados referentes a essas linhas resultantes.
uf = df_acimaMedia.iloc[:,1]
uf
# Out:
# 3     AP
# 6     DF
# 7     ES
# 8     GO
# 10    MG
# 11    MS
# 17    PR
# 18    RJ
# 21    RR
# 22    RS
# 23    SC
# 25    SP
# Name: sigla_uf, dtype: object

# %%
#5. Ordene os dados do DataFrame de 1991 de acordo com o IDH, usando a fun¸c˜ao
#sort values() e mostre a tabela dos 5 primeiros com o .head(5).
idh_crescente = df_filtrado.sort_values('idhm')
idh_crescente.head(5)
# Out:
#      ano sigla_uf  expectativa_vida  populacao_urbana  populacao_rural   idhm
# 9   1991       MA             58.04           1972421          2957832  0.357
# 16  1991       PI             60.71           1367184          1214953  0.362
# 26  1991       TO             60.32            530636           389227  0.369
# 1   1991       AL             58.10           1482033          1032067  0.370
# 14  1991       PB             58.88           2052066          1149048  0.382

# %%
#6. Analise os dados de IDH. Use as fun¸c˜ oes de .min(), .max(), .idxmin() e .idxmax()
#para saber qual o estado de maior e menor IDH no DataFrame do ano de 1991.
menor_idh = df_filtrado.iloc[:,5].idxmin()
maior_idh = df_filtrado.iloc[:,5].idxmax()
print("Estado com maior idh: ", df.iloc[maior_idh,1])
print("Estado com menor idh: ", df.iloc[menor_idh,1])
# Out:
# Estado com maior idh:  DF
# Estado com menor idh:  MA

# %%
#1. Qual a proporcao da Populacao Urbana entre os estados brasileiros?
x = np.array(df_filtrado.iloc[:,1])
y = np.array(df_filtrado.iloc[:,3])

plt.figure(figsize=(10,6))
plt.bar(x, y, )
plt.show()

# %%
# 2. Qual o nível de desigualdade do Brasil?
filtro_91 = df["ano"] == 1991
df_1991 = df[filtro_91].iloc[:,5]

filtro_00 = df["ano"] == 2000
df_2000 = df[filtro_00].iloc[:,5]

filtro_10 = df["ano"] == 2010
df_2010 = df[filtro_10].iloc[:,5]

x = np.array(df_1991)
y = np.array(df_2000)
z = np.array(df_2010)

print("ANO 1991:")
plt.hist(x)
plt.show()
print("ANO 2000:")
plt.hist(y)
plt.show()
print("ANO 2010:")
plt.hist(z)
plt.show()
# Out:
# ANO 1991:
# ANO 2000:
# ANO 2010:

# %% [markdown]
# Em 2010 teve um grande aumento no nível de desigualdade no Brasil em relação a 1991.
#
# 1991 => Entre 0.35 e 0.40
#
# 2000 => 0.50
#
# 2010 => 0.72

# %%
x = np.array(df.iloc[:,5])#idh
y = np.array(df.iloc[:,2])#expectativa de vida

plt.scatter(x, y)
plt.show()

# %% [markdown]
# Observa-se que os dados estão bem próximos um do outro e indo na direção de uma reta crescente, ou seja, existe relação entre o IDH e a expectativa de vida. Quanto maior o IDH, maior a expectativa de vida.

# %%
df_2010 = df[filtro_10]
df_1991 = df[filtro_91]
df_diferenca = df_2010.sort_values('sigla_uf')["expectativa_vida"].reset_index() - df_1991.sort_values('sigla_uf')["expectativa_vida"].reset_index()

x = np.array(df_2010["sigla_uf"])
y = np.array(df_diferenca.iloc[:,1])


plt.figure(figsize=(10,6))
plt.bar(x,y)
plt.show()
# Out:
# <BarContainer object of 27 artists>

# %%
df_dif_filtrado = df_diferenca[ df_diferenca.iloc[:,1] >= 10 ]

all_ufs = []
for i in df_dif_filtrado.index:
  all_ufs.append(df_2010.sort_values('sigla_uf')["sigla_uf"].iloc[i])

x = np.array(all_ufs)
y = np.array(df_dif_filtrado.iloc[:,1])

plt.bar(x,y)
plt.show()
# Out:
# <BarContainer object of 12 artists>
